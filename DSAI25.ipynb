# %%
print("Vageesh")
# Out:
# Vageesh

# %% [markdown]
# ## create a graph

# %% [markdown]
# describe graph

# %% [markdown]
# [Skills Network](https://skills.network)

# %% [markdown]
#  ![Jupyter Logo](https://jupyter.org/assets/homepage/main-logo.svg)

# %% [markdown]
# ![Jupyter Logo](https://jupyter.org/assets/homepage/main-logo.svg)

# %% [markdown]
# | Language | Type          | Use Case             |
# |----------|---------------|----------------------|
# | Python   | General-Purpose | Data Science, AI    |
# | R        | Statistical    | Data Analysis        |
# | Julia    | High-Performance | Scientific Computing |

# %% [markdown]
# - This item uses a dash
# * This item uses an asterisk
# + This item uses a plus sign

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# ## Python programming
#
# ![This is SN labs New Launcher](https://www.wikihow.com/images/thumb/4/41/Get-the-URL-for-Pictures-Draft-Step-1.jpg/v4-460px-Get-the-URL-for-Pictures-Draft-Step-1.jpg)

# %% [markdown]
# [Tools For Data Science](https://www.coursera.org/learn/open-source-tools-for-data-science/home)

# %% [markdown]
# | Tool Name         |  Description                        | new column |
# |-----------------  |        -                            |     -       |
# | Jupyter Notebook  | Web-based interactive computing     |   1        |
# | RStudio           | IDE for R language programming      |2           |
# | Apache Zeppelin   | Web-based notebook for data analysis|3           |

# %% [markdown]
# 1. Install Anaconda
# 2. Launch JupyterLab
# 3. Create a new notebook
# 4. Write and run your first Python cell
# 5. end

# %%
11+4
# Out:
# 15

# %%
import matplotlib.pyplot as plt
a=[1,20000]
b=[1,0]
plt.plot(a,b)
plt.show()
